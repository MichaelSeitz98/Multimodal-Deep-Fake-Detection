# %% [markdown]
# In diesem Notebook wird der Datensatz merged_fake_real.csv verwendet und untersucht wie man Fake-Reviews von Echten Reviews unterscheiden kann. Zuerst wird der Datensatz so vorbeietet um Features zu generieren

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import urllib


# Speziell für Text-Feature-Extraktion
import emoji
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
import string
from nltk import pos_tag, word_tokenize
from nltk.corpus import *
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('stopwords')
from textblob import TextBlob
from transformers import pipeline
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt

# Speziell für Bild-Feature-Extraktion
from PIL import Image
import requests
from fastai.vision.all import *
from fastdownload import download_url
import torch
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import numpy as np
from sklearn.decomposition import PCA


pd.set_option("display.max_rows", None)

# %% [markdown]
# ### Datensatz für Feature Extraction vorbeitet.
#
# Finale Zusammensetzung für base_for_feature_extraction.csv aus real und fake Datensatz

# %%
df = pd.read_csv("merged_fake_real.csv")
print(f"Base Datensatz: {df.shape}")

df.drop(
    [
        "index_fake",
        "org_text",
        "org_stars",
        "sent_score_0",
        "sent_v2",
        "sent_v3",
        "sent_v3.1",
        "prompt_v3",
        "website",
        "dalle_prompt",
        "website",
        "prompt_v2",
        "gpt3_v2",
        "gpt3_v3",
        "gpt3_v3.1",
        "prompt_v4",
        "org_reviewId",
        "sent_v4",
        "keywords",
        "keywords_only",
        "text_length",
        "reviewImageUrls/3",
        "reviewerPhotoUrl",
        "reviewerUrl",
        "reviewerId",
        "temporarilyClosed",
        "reviewsCount",
        "street",
        "state",
        "totalScore",
        "subTitle",
        "description",
        "price",
        "sentiment",
    ],
    axis=1,
    inplace=True,
)

df = df.reindex(
    columns=[
        "label",
        "reviewId",
        "placeId",
        "reviewUrl",
        "url",
        "title",
        "categoryName",
        "genre",
        "text",
        "stars",
        "publishedAtDate",
        "likesCount",
        "name",
        "isLocalGuide",
        "reviewerNumberOfReviews",
        "reviewImageUrls/0",
        "reviewImageUrls/1",
        "reviewImageUrls/2",
    ]
)

print(f"Reduzierter Datensatz als neue Basis für FE: {df.shape}")
print(df.columns)
print(df.dtypes)

df.to_csv("base_for_feature_extraction.csv", index=False)
df.to_excel("base_for_feature_extraction.xlsx", index=False)

# %% [markdown]
# # Tabular: Feature Generierung
#
# 1. aus publishedAt das bestmögliche rausholen
#
# when_on_day_4hbin:
# Midnight: 0-4 hours
# Early morning: 4-8 hours
# Morning: 8-12 hours
# Early afternoon: 12-16 hours
# Late afternoon: 16-20 hours
# Evening: 20-24 hours -->

# %%
df = pd.read_csv("base_for_feature_extraction.csv")
print(df["publishedAtDate"][977])

df["publishedAtDate"] = pd.to_datetime(
    df["publishedAtDate"], format="%Y-%m-%dT%H:%M:%S"
)

df["year"] = df["publishedAtDate"].dt.year
df["month"] = df["publishedAtDate"].dt.month
df["dayofweek"] = df["publishedAtDate"].dt.dayofweek
df["elapsed_days"] = (datetime.today() - df["publishedAtDate"]).dt.days
df["when_on_day_4hbin"] = pd.cut(
    df["publishedAtDate"].dt.hour,
    bins=[-1, 4, 8, 12, 16, 20, 24],
    labels=[0, 1, 2, 3, 4, 5],
)

df["when_on_day_hour"] = df["publishedAtDate"].dt.hour

print(df["when_on_day_4hbin"].isna().sum())
print(df.loc[df["when_on_day_4hbin"].isna(), "publishedAtDate"])

print(
    df[
        [
            "publishedAtDate",
            "year",
            "month",
            "dayofweek",
            "elapsed_days",
            "when_on_day_4hbin",
            "when_on_day_hour",
        ]
    ].head(10)
)

df.to_csv("feature_enriched_tab.csv", index=False)
df.to_excel("feature_enriched_tab.xlsx", index=False)

# %% [markdown]
# # Bild: Feature Generierung
#
# Feature Extrahieren über pretrained ResNet-18 Architektur und in tabellerischer Form im Dataframe abspeichern.

# %%
df = pd.read_csv("feature_enriched_tab.csv")
image_urls = df["reviewImageUrls/0"]

# %%
resnet = models.resnet18(pretrained=True)

# Die letzte Klassifikationsschicht entfernen
modules = list(resnet.children())[:-1]
resnet = torch.nn.Sequential(*modules)
resnet.eval()

def extract_image_features(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    img = transforms.ToTensor()(img)
    img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
    img = img.unsqueeze(0)

    # Hier werden die Features extrahiert
    with torch.no_grad():
        features = resnet(img)
        features = features.squeeze().numpy()

    return features

# %%
counter = 0
feature_vectors = []
for image_url in image_urls:
    try:
        counter += 1
        print(f'{counter}:\tExtracting features from {image_url}')
        features = extract_image_features(image_url)
    except:
        print(f'Error extracting features from {image_url}. Replaces with NaN.')
        features = np.full((512,), np.nan)
    feature_vectors.append(features)

feature_df = pd.DataFrame(feature_vectors, columns=[f'feature_{i}' for i in range(512)])

# %%
new_df = pd.concat([df, feature_df], axis=1)
print("added features to the original dataset.")

new_df.to_csv('feature_enriched_tab_img.csv', index=False)
new_df.to_excel('feature_enriched_tab_img.xlsx', index=False)

# %% [markdown]
# ## Feature für die 2. Bilder werden ebenfalls extrahiert
#
# Ziel: zu prüfen, ob mit auf der reviewImageUrls/2 die Detektion genauso gut funktioniert, bei anderer Prompt für Dalle-2-Bilder.
# Antwort: Ja! Auch hier ähnlich hohe Vorhersagekraft

# %%
df = pd.read_csv("features_enriched_tab_img_text_preproc.csv")

pd.set_option("display.width", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_colwidth", 1000)
              
print(df.columns[:20])
print(df["label"][719])
df = pd.read_csv("features_enriched_tab_img_text_preproc.csv")
mask = df["label"] == 0
df.loc[mask, "reviewImageUrls/2"] = df.loc[mask, "reviewImageUrls/0"]
image_urls = df["reviewImageUrls/2"]

print(df["reviewImageUrls/2"])
# Out:
# Index(['label', 'reviewId', 'placeId', 'reviewUrl', 'url', 'title', 'categoryName', 'genre', 'text', 'tab_star', 'publishedAtDate', 'tab_likesCount', 'name', 'tab_isLocalGuide', 'tab_reviewerNumberOfReviews', 'reviewImageUrls/0', 'reviewImageUrls/1', 'reviewImageUrls/2', 'tab_year', 'tab_month'], dtype='object')
# 0
# 0        https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/0_ChZDSUhNMG9nS0VJQ0FnSURJanBQb1pBEAEF_fake_reviewImageUrls_2.png
# 1       https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/1_ChdDSUhNMG9nS0VJQ0FnSUNZLWRHY3VRRRABF_fake_reviewImageUrls_2.png
# 2       https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/2_ChdDSUhNMG9nS0VJQ0FnSUNtc04zQXNRRRABF_fake_reviewImageUrls_2.png
# 3        https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/3_ChZDSUhNMG9nS0VJQ0FnSUNvb05hU1pREAEF_fake_reviewImageUrls_2.png
# 4        https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/4_ChZDSUhNMG9nS0VJQ0FnSUQyazc3ZE53EAEF_fake_reviewImageUrls_2.png
#                                                                                                ...
# 1403                                                                                     https://lh5.googleusercontent.com/p/AF1QipPeYm4PQSinsQtYYNQ4LYl9lyCo6dhJDBamYVQC=w256-h256-p-k-no
# 1404                                                                                     https://lh5.googleusercontent.com/p/AF1QipMcT6mnSf7KQ1bq1t1wzcEqcbTXVh0zfPAwx0H4=w256-h256-p-k-no
# 1405                                                                                     https://lh5.googleusercontent.com/p/AF1QipNSfoGJPcFoQxzbJB80aG_kSTkv1hrc-wPAC-EL=w256-h256-p-k-no
# 1406                                                                                     https://lh5.googleusercontent.com/p/AF1QipNGi9yHsKX5RiDRmHiPlJuW0ylWnNy2ZFVUKrYj=w256-h256-p-k-no
# 1407                                                                                     https://lh5.googleusercontent.com/p/AF1QipNdt-skNxsWFOlehP7axXhRLqTaalORDTQvBug7=w256-h256-p-k-no
# Name: reviewImageUrls/2, Length: 1408, dtype: object

# %%
resnet = models.resnet18(pretrained=True)
modules = list(resnet.children())[:-1]
resnet = torch.nn.Sequential(*modules)
resnet.eval()

def extract_image_features(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    img = transforms.ToTensor()(img)
    img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
    img = img.unsqueeze(0)
    with torch.no_grad():
        features = resnet(img)
        features = features.squeeze().numpy()

    return features
# Out:
# c:\Users\michi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\michi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# **Die Features der Zweiten Bilder, die auf reviewImageUrls/2 gespeichert sind, werden zu "img_feature_0" bis "img_feature_511"**

# %%
counter = 0
feature_vectors = []
for image_url in image_urls:
    try:
        counter += 1
        print(f'{counter}:\tExtracting features from {image_url}')
        features = extract_image_features(image_url)
    except:
        print(f'Error extracting features from {image_url}. Replaces with NaN.')
        features = np.full((512,), np.nan)
    feature_vectors.append(features)

feature_df = pd.DataFrame(feature_vectors, columns=[f'img_feature_{i}' for i in range(512)])
# Out:
# 1:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/0_ChZDSUhNMG9nS0VJQ0FnSURJanBQb1pBEAEF_fake_reviewImageUrls_2.png
# 2:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/1_ChdDSUhNMG9nS0VJQ0FnSUNZLWRHY3VRRRABF_fake_reviewImageUrls_2.png
# 3:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/2_ChdDSUhNMG9nS0VJQ0FnSUNtc04zQXNRRRABF_fake_reviewImageUrls_2.png
# 4:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/3_ChZDSUhNMG9nS0VJQ0FnSUNvb05hU1pREAEF_fake_reviewImageUrls_2.png
# 5:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/4_ChZDSUhNMG9nS0VJQ0FnSUQyazc3ZE53EAEF_fake_reviewImageUrls_2.png
# 6:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/5_ChdDSUhNMG9nS0VJQ0FnSURHNHJDbDV3RRABF_fake_reviewImageUrls_2.png
# 7:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/6_ChdDSUhNMG9nS0VJQ0FnSURVeDZhNV9BRRABF_fake_reviewImageUrls_2.png
# 8:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/7_ChdDSUhNMG9nS0VJQ0FnSURtM3NxbnRRRRABF_fake_reviewImageUrls_2.png
# 9:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/8_ChZDSUhNMG9nS0VJQ0FnSURxb3ZiNEhnEAEF_fake_reviewImageUrls_2.png
# 10:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/9_ChZDSUhNMG9nS0VJQ0FnSUNld3Vib0ZBEAEF_fake_reviewImageUrls_2.png
# 11:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/10_ChdDSUhNMG9nS0VJQ0FnSUQyNGI2SnFnRRABF_fake_reviewImageUrls_2.png
# 12:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/11_ChZDSUhNMG9nS0VJQ0FnSUQwOE1iNE93EAEF_fake_reviewImageUrls_2.png
# 13:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/12_ChdDSUhNMG9nS0VJQ0FnSURVNzVMR29RRRABF_fake_reviewImageUrls_2.png
# 14:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/13_ChZDSUhNMG9nS0VJQ0FnSUQ2emVUUmRREAEF_fake_reviewImageUrls_2.png
# 15:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/14_ChZDSUhNMG9nS0VJQ0FnSUNCLV9fZlJ3EAEF_fake_reviewImageUrls_2.png
# 16:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/15_ChdDSUhNMG9nS0VJQ0FnSURxMU42S3FRRRABF_fake_reviewImageUrls_2.png
# 17:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/16_ChZDSUhNMG9nS0VJQ0FnSUNtOHZtck53EAEF_fake_reviewImageUrls_2.png
# 18:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/17_ChZDSUhNMG9nS0VJQ0FnSUM4MHFQU053EAEF_fake_reviewImageUrls_2.png
# 19:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/18_ChdDSUhNMG9nS0VJQ0FnSUNCblpyLXZBRRABF_fake_reviewImageUrls_2.png
# 20:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/19_ChdDSUhNMG9nS0VJQ0FnSURvNkpQc29BRRABF_fake_reviewImageUrls_2.png
# 21:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/20_ChdDSUhNMG9nS0VJQ0FnSUN1d2RyaXNRRRABF_fake_reviewImageUrls_2.png
# 22:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/21_ChZDSUhNMG9nS0VJQ0FnSURDaWJ2MkF3EAEF_fake_reviewImageUrls_2.png
# 23:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/22_ChZDSUhNMG9nS0VJQ0FnSUNnOE9yelB3EAEF_fake_reviewImageUrls_2.png
# 24:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/23_ChdDSUhNMG9nS0VJQ0FnSUQ2cUlTUi1BRRABF_fake_reviewImageUrls_2.png
# 25:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/24_ChdDSUhNMG9nS0VJQ0FnSUNNNTdQRDJRRRABF_fake_reviewImageUrls_2.png
# 26:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/25_ChZDSUhNMG9nS0VJQ0FnSUQtNnZTVmFnEAEF_fake_reviewImageUrls_2.png
# 27:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/26_ChdDSUhNMG9nS0VJQ0FnSUNTeU9yUjhnRRABF_fake_reviewImageUrls_2.png
# 28:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/27_ChZDSUhNMG9nS0VJQ0FnSUMyckpXeWF3EAEF_fake_reviewImageUrls_2.png
# 29:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/28_ChZDSUhNMG9nS0VJQ0FnSURReHRLcE53EAEF_fake_reviewImageUrls_2.png
# 30:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/29_ChdDSUhNMG9nS0VJQ0FnSURjM1BPZ3BBRRABF_fake_reviewImageUrls_2.png
# 31:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/30_ChZDSUhNMG9nS0VJQ0FnSURLLXVLSGFREAEF_fake_reviewImageUrls_2.png
# 32:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/31_ChZDSUhNMG9nS0VJQ0FnSURlNU5mN0xnEAEF_fake_reviewImageUrls_2.png
# 33:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/32_ChdDSUhNMG9nS0VJQ0FnSURrenM2d21BRRABF_fake_reviewImageUrls_2.png
# 34:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/33_ChdDSUhNMG9nS0VJQ0FnSUNvZ0lDR3lnRRABF_fake_reviewImageUrls_2.png
# 35:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/34_ChZDSUhNMG9nS0VJQ0FnSURZbE82U01REAEF_fake_reviewImageUrls_2.png
# 36:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/35_ChdDSUhNMG9nS0VJQ0FnSUNZd3VQdndRRRABF_fake_reviewImageUrls_2.png
# 37:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/36_ChZDSUhNMG9nS0VJQ0FnSURxNmFib0JBEAEF_fake_reviewImageUrls_2.png
# 38:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/37_ChdDSUhNMG9nS0VJQ0FnSUNHODducTNBRRABF_fake_reviewImageUrls_2.png
# 39:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/38_ChZDSUhNMG9nS0VJQ0FnSUMtN3VpT1hnEAEF_fake_reviewImageUrls_2.png
# 40:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/39_ChdDSUhNMG9nS0VJQ0FnSUNPLXAycm5BRRABF_fake_reviewImageUrls_2.png
# 41:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/40_ChdDSUhNMG9nS0VJQ0FnSUQtcl9Xam1RRRABF_fake_reviewImageUrls_2.png
# 42:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/41_ChZDSUhNMG9nS0VJQ0FnSUM0czdlRElREAEF_fake_reviewImageUrls_2.png
# 43:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/42_ChZDSUhNMG9nS0VJQ0FnSUNoM2NqeWZBEAEF_fake_reviewImageUrls_2.png
# 44:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/43_ChZDSUhNMG9nS0VJQ0FnSURRdTh6UEJnEAEF_fake_reviewImageUrls_2.png
# 45:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/44_ChdDSUhNMG9nS0VJQ0FnSUNRbHRYd25RRRABF_fake_reviewImageUrls_2.png
# 46:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/45_ChdDSUhNMG9nS0VJQ0FnSUN3cTgtSXZnRRABF_fake_reviewImageUrls_2.png
# 47:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/46_ChZDSUhNMG9nS0VJQ0FnSURXazhqTkx3EAEF_fake_reviewImageUrls_2.png
# 48:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/47_ChdDSUhNMG9nS0VJQ0FnSUNNcGN5NXdBRRABF_fake_reviewImageUrls_2.png
# 49:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/48_ChdDSUhNMG9nS0VJQ0FnSURPbXAzRm13RRABF_fake_reviewImageUrls_2.png
# 50:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/49_ChZDSUhNMG9nS0VJQ0FnSUMwNUktRkVBEAEF_fake_reviewImageUrls_2.png
# 51:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/50_ChZDSUhNMG9nS0VJQ0FnSUQyanYzQUNBEAEF_fake_reviewImageUrls_2.png
# 52:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/51_ChZDSUhNMG9nS0VJQ0FnSUQybnBxdlpREAEF_fake_reviewImageUrls_2.png
# 53:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/52_ChdDSUhNMG9nS0VJQ0FnSURnd3AyNWl3RRABF_fake_reviewImageUrls_2.png
# 54:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/53_ChdDSUhNMG9nS0VJQ0FnSURBN196YWlnRRABF_fake_reviewImageUrls_2.png
# 55:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/54_ChZDSUhNMG9nS0VJQ0FnSUQtelBXd2NBEAEF_fake_reviewImageUrls_2.png
# 56:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/55_ChZDSUhNMG9nS0VJQ0FnSUNJMTZuY0hBEAEF_fake_reviewImageUrls_2.png
# 57:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/56_ChZDSUhNMG9nS0VJQ0FnSURBbGNhX0dnEAEF_fake_reviewImageUrls_2.png
# 58:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/58_ChZDSUhNMG9nS0VJQ0FnSUNvbi1YeFRnEAEF_fake_reviewImageUrls_2.png
# 59:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/59_ChdDSUhNMG9nS0VJQ0FnSURXaV9mQ2lnRRABF_fake_reviewImageUrls_2.png
# 60:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/60_ChZDSUhNMG9nS0VJQ0FnSURRdmV1MUZ3EAEF_fake_reviewImageUrls_2.png
# 61:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/61_ChZDSUhNMG9nS0VJQ0FnSURBbDlEREVBEAEF_fake_reviewImageUrls_2.png
# 62:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/62_ChZDSUhNMG9nS0VJQ0FnSUNJdHRTV2VnEAEF_fake_reviewImageUrls_2.png
# 63:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/63_ChdDSUhNMG9nS0VJQ0FnSURZMjlIM213RRABF_fake_reviewImageUrls_2.png
# 64:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/64_ChZDSUhNMG9nS0VJQ0FnSUQ2ajdiT1dnEAEF_fake_reviewImageUrls_2.png
# 65:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/65_ChdDSUhNMG9nS0VJQ0FnSURndHZ1anJ3RRABF_fake_reviewImageUrls_2.png
# 66:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/66_ChZDSUhNMG9nS0VJQ0FnSUN3bHVxeUNREAEF_fake_reviewImageUrls_2.png
# 67:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/67_ChdDSUhNMG9nS0VJQ0FnSUN3MHJLQ2xBRRABF_fake_reviewImageUrls_2.png
# 68:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/68_ChdDSUhNMG9nS0VJQ0FnSURRdU9iTzFBRRABF_fake_reviewImageUrls_2.png
# 69:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/69_ChdDSUhNMG9nS0VJQ0FnSUMyMS0tRzRBRRABF_fake_reviewImageUrls_2.png
# 70:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/70_ChdDSUhNMG9nS0VJQ0FnSUN1bnNxeG1RRRABF_fake_reviewImageUrls_2.png
# 71:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/71_ChdDSUhNMG9nS0VJQ0FnSURBc0pfZHNnRRABF_fake_reviewImageUrls_2.png
# 72:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/72_ChdDSUhNMG9nS0VJQ0FnSURRNzd1am13RRABF_fake_reviewImageUrls_2.png
# 73:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/73_ChdDSUhNMG9nS0VJQ0FnSUNRakktUXZnRRABF_fake_reviewImageUrls_2.png
# 74:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/74_ChdDSUhNMG9nS0VJQ0FnSUN1OF83Mm93RRABF_fake_reviewImageUrls_2.png
# 75:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/75_ChZDSUhNMG9nS0VJQ0FnSUNla05iY0xREAEF_fake_reviewImageUrls_2.png
# 76:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/76_ChZDSUhNMG9nS0VJQ0FnSUNtdU9maU5nEAEF_fake_reviewImageUrls_2.png
# 77:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/77_ChZDSUhNMG9nS0VJQ0FnSUM2aTctX1dREAEF_fake_reviewImageUrls_2.png
# 78:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/78_ChdDSUhNMG9nS0VJQ0FnSUMyeGNtV2l3RRABF_fake_reviewImageUrls_2.png
# 79:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/79_ChdDSUhNMG9nS0VJQ0FnSUNTeU9uRC13RRABF_fake_reviewImageUrls_2.png
# 80:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/80_ChZDSUhNMG9nS0VJQ0FnSUQ2OTVyUEN3EAEF_fake_reviewImageUrls_2.png
# 81:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/81_ChZDSUhNMG9nS0VJQ0FnSUM2cnNmbU9nEAEF_fake_reviewImageUrls_2.png
# 82:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/82_ChZDSUhNMG9nS0VJQ0FnSUNJdjdMNFJREAEF_fake_reviewImageUrls_2.png
# 83:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/83_ChdDSUhNMG9nS0VJQ0FnSURXODZlbWp3RRABF_fake_reviewImageUrls_2.png
# 84:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/84_ChdDSUhNMG9nS0VJQ0FnSUNoXzRMenV3RRABF_fake_reviewImageUrls_2.png
# 85:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/85_ChZDSUhNMG9nS0VJQ0FnSUN3czZTWUNREAEF_fake_reviewImageUrls_2.png
# 86:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/86_ChdDSUhNMG9nS0VJQ0FnSURxaktpUHFnRRABF_fake_reviewImageUrls_2.png
# 87:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/87_ChZDSUhNMG9nS0VJQ0FnSURPcm9xa1R3EAEF_fake_reviewImageUrls_2.png
# 88:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/88_ChdDSUhNMG9nS0VJQ0FnSURLdEllcjdBRRABF_fake_reviewImageUrls_2.png
# 89:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/89_ChZDSUhNMG9nS0VJQ0FnSURpbEszV2NnEAEF_fake_reviewImageUrls_2.png
# 90:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/90_ChZDSUhNMG9nS0VJQ0FnSUN1d2NHUUJBEAEF_fake_reviewImageUrls_2.png
# 91:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/91_ChdDSUhNMG9nS0VJQ0FnSUNRcTcyMzJBRRABF_fake_reviewImageUrls_2.png
# 92:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/92_ChdDSUhNMG9nS0VJQ0FnSUNoNXBpcDl3RRABF_fake_reviewImageUrls_2.png
# 93:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/93_ChZDSUhNMG9nS0VJQ0FnSURPdHNtaldREAEF_fake_reviewImageUrls_2.png
# 94:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/94_ChZDSUhNMG9nS0VJQ0FnSURDN0ttc0N3EAEF_fake_reviewImageUrls_2.png
# 95:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/95_ChZDSUhNMG9nS0VJQ0FnSURjNXBHS0hnEAEF_fake_reviewImageUrls_2.png
# 96:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/96_ChdDSUhNMG9nS0VJQ0FnSUN3MWRlU21BRRABF_fake_reviewImageUrls_2.png
# 97:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/97_ChZDSUhNMG9nS0VJQ0FnSUNnNWZUaVBnEAEF_fake_reviewImageUrls_2.png
# 98:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/98_ChdDSUhNMG9nS0VJQ0FnSUNLeFBMSXFRRRABF_fake_reviewImageUrls_2.png
# 99:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/99_ChdDSUhNMG9nS0VJQ0FnSURvdjRtV3FRRRABF_fake_reviewImageUrls_2.png
# 100:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/100_ChZDSUhNMG9nS0VJQ0FnSURzamJqeWFREAEF_fake_reviewImageUrls_2.png
# 101:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/101_ChZDSUhNMG9nS0VJQ0FnSUNoOVBIX1h3EAEF_fake_reviewImageUrls_2.png
# 102:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/102_ChdDSUhNMG9nS0VJQ0FnSUR1OXNQNWtRRRABF_fake_reviewImageUrls_2.png
# 103:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/103_ChdDSUhNMG9nS0VJQ0FnSUNxazVDc3BRRRABF_fake_reviewImageUrls_2.png
# 104:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/104_ChZDSUhNMG9nS0VJQ0FnSUNlcV9XTEJ3EAEF_fake_reviewImageUrls_2.png
# 105:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/105_ChdDSUhNMG9nS0VJQ0FnSUNoM1phZW5RRRABF_fake_reviewImageUrls_2.png
# 106:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/106_ChdDSUhNMG9nS0VJQ0FnSURob05MR3FBRRABF_fake_reviewImageUrls_2.png
# 107:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/107_ChdDSUhNMG9nS0VJQ0FnSUQyaktXeml3RRABF_fake_reviewImageUrls_2.png
# 108:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/108_ChdDSUhNMG9nS0VJQ0FnSURjajZQXzJBRRABF_fake_reviewImageUrls_2.png
# 109:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/109_ChZDSUhNMG9nS0VJQ0FnSUNhbW9YU2JREAEF_fake_reviewImageUrls_2.png
# 110:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/110_ChdDSUhNMG9nS0VJQ0FnSUNlNTlEdjN3RRABF_fake_reviewImageUrls_2.png
# 111:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/111_ChZDSUhNMG9nS0VJQ0FnSUMyLXZDamZ3EAEF_fake_reviewImageUrls_2.png
# 112:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/112_ChdDSUhNMG9nS0VJQ0FnSURzcHFuM29BRRABF_fake_reviewImageUrls_2.png
# 113:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/113_ChdDSUhNMG9nS0VJQ0FnSUNvMl9XZWhnRRABF_fake_reviewImageUrls_2.png
# 114:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/114_ChZDSUhNMG9nS0VJQ0FnSURDLWRmT0VBEAEF_fake_reviewImageUrls_2.png
# 115:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/115_ChdDSUhNMG9nS0VJQ0FnSURveVB1Tzl3RRABF_fake_reviewImageUrls_2.png
# 116:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/116_ChZDSUhNMG9nS0VJQ0FnSURZbmZQNFlBEAEF_fake_reviewImageUrls_2.png
# 117:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/117_ChdDSUhNMG9nS0VJQ0FnSUNZMFpLVmdnRRABF_fake_reviewImageUrls_2.png
# 118:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/118_ChdDSUhNMG9nS0VJQ0FnSURJcF9EaWlRRRABF_fake_reviewImageUrls_2.png
# 119:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/119_ChZDSUhNMG9nS0VJQ0FnSUNLMF9PTkx3EAEF_fake_reviewImageUrls_2.png
# 120:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/120_ChZDSUhNMG9nS0VJQ0FnSUNvdllfYWJBEAEF_fake_reviewImageUrls_2.png
# 121:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/121_ChdDSUhNMG9nS0VJQ0FnSUNBLUozSXh3RRABF_fake_reviewImageUrls_2.png
# 122:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/122_ChZDSUhNMG9nS0VJQ0FnSUNzLWRqOFhREAEF_fake_reviewImageUrls_2.png
# 123:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/123_ChdDSUhNMG9nS0VJQ0FnSURXaWNPMXN3RRABF_fake_reviewImageUrls_2.png
# 124:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/124_ChZDSUhNMG9nS0VJQ0FnSURlbDU3ZlFREAEF_fake_reviewImageUrls_2.png
# 125:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/125_ChdDSUhNMG9nS0VJQ0FnSUN3bmFIc2d3RRABF_fake_reviewImageUrls_2.png
# 126:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/126_ChZDSUhNMG9nS0VJQ0FnSURJeTczWUlREAEF_fake_reviewImageUrls_2.png
# 127:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/127_ChdDSUhNMG9nS0VJQ0FnSURodmJfYTlRRRABF_fake_reviewImageUrls_2.png
# 128:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/128_ChZDSUhNMG9nS0VJQ0FnSUNJb3BySlFBEAEF_fake_reviewImageUrls_2.png
# 129:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/129_ChdDSUhNMG9nS0VJQ0FnSURNbDhYY3RBRRABF_fake_reviewImageUrls_2.png
# 130:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/130_ChdDSUhNMG9nS0VJQ0FnSURxcUxURG5BRRABF_fake_reviewImageUrls_2.png
# 131:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/131_ChdDSUhNMG9nS0VJQ0FnSUN3NjdpS3FnRRABF_fake_reviewImageUrls_2.png
# 132:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/132_ChdDSUhNMG9nS0VJQ0FnSUNxeEx2MHJnRRABF_fake_reviewImageUrls_2.png
# 133:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/133_ChZDSUhNMG9nS0VJQ0FnSUNRXzRLeVhBEAEF_fake_reviewImageUrls_2.png
# 134:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/134_ChZDSUhNMG9nS0VJQ0FnSUM0c2ZETERnEAEF_fake_reviewImageUrls_2.png
# 135:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/135_ChdDSUhNMG9nS0VJQ0FnSURRcVpXRHFBRRABF_fake_reviewImageUrls_2.png
# 136:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/136_ChZDSUhNMG9nS0VJQ0FnSUQwdG8tVlN3EAEF_fake_reviewImageUrls_2.png
# 137:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/137_ChZDSUhNMG9nS0VJQ0FnSURJeEk3c0RREAEF_fake_reviewImageUrls_2.png
# 138:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/138_ChZDSUhNMG9nS0VJQ0FnSUR1dE5TTVd3EAEF_fake_reviewImageUrls_2.png
# 139:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/139_ChZDSUhNMG9nS0VJQ0FnSUR1dU5pcExnEAEF_fake_reviewImageUrls_2.png
# 140:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/140_ChdDSUhNMG9nS0VJQ0FnSUNHcHRySHlnRRABF_fake_reviewImageUrls_2.png
# 141:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/141_ChZDSUhNMG9nS0VJQ0FnSUN5aGRMdWNREAEF_fake_reviewImageUrls_2.png
# 142:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/142_ChdDSUhNMG9nS0VJQ0FnSUNZcWZENHFBRRABF_fake_reviewImageUrls_2.png
# 143:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/143_ChZDSUhNMG9nS0VJQ0FnSUMyNXNTeUpBEAEF_fake_reviewImageUrls_2.png
# 144:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/144_ChdDSUhNMG9nS0VJQ0FnSUNxdHN5VDl3RRABF_fake_reviewImageUrls_2.png
# 145:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/145_ChZDSUhNMG9nS0VJQ0FnSURXNXUtVEN3EAEF_fake_reviewImageUrls_2.png
# 146:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/146_ChdDSUhNMG9nS0VJQ0FnSURoMDhpQ2tnRRABF_fake_reviewImageUrls_2.png
# 147:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/147_ChZDSUhNMG9nS0VJQ0FnSUN1aHB1SEVnEAEF_fake_reviewImageUrls_2.png
# 148:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/148_ChZDSUhNMG9nS0VJQ0FnSUNlOGRHck5REAEF_fake_reviewImageUrls_2.png
# 149:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/149_ChZDSUhNMG9nS0VJQ0FnSURXMjd5VVZnEAEF_fake_reviewImageUrls_2.png
# 150:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/150_ChdDSUhNMG9nS0VJQ0FnSURJbkpqZ29BRRABF_fake_reviewImageUrls_2.png
# 151:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/151_ChdDSUhNMG9nS0VJQ0FnSUNpNE1xSV9BRRABF_fake_reviewImageUrls_2.png
# 152:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/152_ChdDSUhNMG9nS0VJQ0FnSUMwck5YazZRRRABF_fake_reviewImageUrls_2.png
# 153:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/153_ChdDSUhNMG9nS0VJQ0FnSUNndi0tY3pnRRABF_fake_reviewImageUrls_2.png
# 154:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/154_ChZDSUhNMG9nS0VJQ0FnSUM4X0otYkhnEAEF_fake_reviewImageUrls_2.png
# 155:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/155_ChZDSUhNMG9nS0VJQ0FnSUNldk9PVElREAEF_fake_reviewImageUrls_2.png
# 156:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/156_ChdDSUhNMG9nS0VJQ0FnSURTMDZheTlRRRABF_fake_reviewImageUrls_2.png
# 157:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/157_ChdDSUhNMG9nS0VJQ0FnSUR5NElmdWpnRRABF_fake_reviewImageUrls_2.png
# 158:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/158_ChdDSUhNMG9nS0VJQ0FnSUQweEt1eHhRRRABF_fake_reviewImageUrls_2.png
# 159:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/159_ChdDSUhNMG9nS0VJQ0FnSUNvLWFiVjlBRRABF_fake_reviewImageUrls_2.png
# 160:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/160_ChZDSUhNMG9nS0VJQ0FnSURnbTdDQlNREAEF_fake_reviewImageUrls_2.png
# 161:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/161_ChdDSUhNMG9nS0VJQ0FnSUNnMWVQS19RRRABF_fake_reviewImageUrls_2.png
# 162:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/162_ChZDSUhNMG9nS0VJQ0FnSURlNnNmb1FBEAEF_fake_reviewImageUrls_2.png
# 163:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/163_ChZDSUhNMG9nS0VJQ0FnSURJaTZUREpREAEF_fake_reviewImageUrls_2.png
# 164:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/164_ChdDSUhNMG9nS0VJQ0FnSUQwX1AzQnV3RRABF_fake_reviewImageUrls_2.png
# 165:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/165_ChdDSUhNMG9nS0VJQ0FnSUNobE1xdTd3RRABF_fake_reviewImageUrls_2.png
# 166:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/166_ChZDSUhNMG9nS0VJQ0FnSUM4b29EZ093EAEF_fake_reviewImageUrls_2.png
# 167:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/167_ChdDSUhNMG9nS0VJQ0FnSUNRb05qRnBRRRABF_fake_reviewImageUrls_2.png
# 168:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/168_ChZDSUhNMG9nS0VJQ0FnSUNLbEtYN0p3EAEF_fake_reviewImageUrls_2.png
# 169:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/169_ChdDSUhNMG9nS0VJQ0FnSURjbS03Si1nRRABF_fake_reviewImageUrls_2.png
# 170:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/170_ChZDSUhNMG9nS0VJQ0FnSUMtcmFMVEl3EAEF_fake_reviewImageUrls_2.png
# 171:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/171_ChZDSUhNMG9nS0VJQ0FnSURobWZ6dGN3EAEF_fake_reviewImageUrls_2.png
# 172:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/172_ChZDSUhNMG9nS0VJQ0FnSUN3b2Q2dVVREAEF_fake_reviewImageUrls_2.png
# 173:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/173_ChdDSUhNMG9nS0VJQ0FnSUNvcllYRXNnRRABF_fake_reviewImageUrls_2.png
# 174:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/174_ChZDSUhNMG9nS0VJQ0FnSUM0cU9TbGVnEAEF_fake_reviewImageUrls_2.png
# 175:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/175_ChZDSUhNMG9nS0VJQ0FnSURxeHZYRkpnEAEF_fake_reviewImageUrls_2.png
# 176:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/176_ChZDSUhNMG9nS0VJQ0FnSUM2dS0zeVRREAEF_fake_reviewImageUrls_2.png
# 177:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/177_ChdDSUhNMG9nS0VJQ0FnSUMwdGRhQ2lnRRABF_fake_reviewImageUrls_2.png
# 178:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/178_ChZDSUhNMG9nS0VJQ0FnSUNFX09pdmRREAEF_fake_reviewImageUrls_2.png
# 179:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/179_ChZDSUhNMG9nS0VJQ0FnSUNCbXN5M013EAEF_fake_reviewImageUrls_2.png
# 180:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/180_ChdDSUhNMG9nS0VJQ0FnSUQ2eWNySV9nRRABF_fake_reviewImageUrls_2.png
# 181:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/181_ChZDSUhNMG9nS0VJQ0FnSURBbFk2OEhREAEF_fake_reviewImageUrls_2.png
# 182:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/182_ChZDSUhNMG9nS0VJQ0FnSUN3MHU2bUZREAEF_fake_reviewImageUrls_2.png
# 183:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/183_ChdDSUhNMG9nS0VJQ0FnSURNcXFUWXRRRRABF_fake_reviewImageUrls_2.png
# 184:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/184_ChZDSUhNMG9nS0VJQ0FnSURRaVp6WFVnEAEF_fake_reviewImageUrls_2.png
# 185:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/185_ChdDSUhNMG9nS0VJQ0FnSURXaWV2UTZnRRABF_fake_reviewImageUrls_2.png
# 186:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/186_ChZDSUhNMG9nS0VJQ0FnSURJMDdpeldBEAEF_fake_reviewImageUrls_2.png
# 187:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/187_ChdDSUhNMG9nS0VJQ0FnSUN3Ni03WF9BRRABF_fake_reviewImageUrls_2.png
# 188:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/188_ChdDSUhNMG9nS0VJQ0FnSUNPbmJXSDJnRRABF_fake_reviewImageUrls_2.png
# 189:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/189_ChZDSUhNMG9nS0VJQ0FnSUNRellUbkV3EAEF_fake_reviewImageUrls_2.png
# 190:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/190_ChdDSUhNMG9nS0VJQ0FnSURFLW9lVHFBRRABF_fake_reviewImageUrls_2.png
# 191:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/191_ChdDSUhNMG9nS0VJQ0FnSURxbE1ESDlBRRABF_fake_reviewImageUrls_2.png
# 192:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/192_ChZDSUhNMG9nS0VJQ0FnSURZdmZmNFJREAEF_fake_reviewImageUrls_2.png
# 193:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/193_ChdDSUhNMG9nS0VJQ0FnSUNLc2VUTGp3RRABF_fake_reviewImageUrls_2.png
# 194:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/194_ChZDSUhNMG9nS0VJQ0FnSUNneXMyNlFREAEF_fake_reviewImageUrls_2.png
# 195:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/195_ChZDSUhNMG9nS0VJQ0FnSUNnak1QQ2NnEAEF_fake_reviewImageUrls_2.png
# 196:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/196_ChZDSUhNMG9nS0VJQ0FnSURRMmRPbE53EAEF_fake_reviewImageUrls_2.png
# 197:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/197_ChZDSUhNMG9nS0VJQ0FnSURRcVBuQ0pREAEF_fake_reviewImageUrls_2.png
# 198:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/198_ChdDSUhNMG9nS0VJQ0FnSURoaC15bDBBRRABF_fake_reviewImageUrls_2.png
# 199:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/199_ChdDSUhNMG9nS0VJQ0FnSUNJbjRETDZBRRABF_fake_reviewImageUrls_2.png
# 200:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/200_ChZDSUhNMG9nS0VJQ0FnSUNJaG9MN1h3EAEF_fake_reviewImageUrls_2.png
# 201:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/201_ChZDSUhNMG9nS0VJQ0FnSUQyeU5hUlZREAEF_fake_reviewImageUrls_2.png
# 202:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/202_ChdDSUhNMG9nS0VJQ0FnSUM4eEp6RW1RRRABF_fake_reviewImageUrls_2.png
# 203:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/203_ChZDSUhNMG9nS0VJQ0FnSUNzbGJDY053EAEF_fake_reviewImageUrls_2.png
# 204:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/204_ChZDSUhNMG9nS0VJQ0FnSUQ2NXNXcVFBEAEF_fake_reviewImageUrls_2.png
# 205:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/205_ChZDSUhNMG9nS0VJQ0FnSUNjbDRhS0ZBEAEF_fake_reviewImageUrls_2.png
# 206:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/206_ChdDSUhNMG9nS0VJQ0FnSUQ2MFBMZjFRRRABF_fake_reviewImageUrls_2.png
# 207:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/207_ChdDSUhNMG9nS0VJQ0FnSURTaVotbTJRRRABF_fake_reviewImageUrls_2.png
# 208:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/208_ChZDSUhNMG9nS0VJQ0FnSUR5MTRudUdnEAEF_fake_reviewImageUrls_2.png
# 209:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/209_ChZDSUhNMG9nS0VJQ0FnSUNhLUx2SEh3EAEF_fake_reviewImageUrls_2.png
# 210:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/210_ChdDSUhNMG9nS0VJQ0FnSURPZzdQa25nRRABF_fake_reviewImageUrls_2.png
# 211:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/211_ChdDSUhNMG9nS0VJQ0FnSURxMHBlbHVBRRABF_fake_reviewImageUrls_2.png
# 212:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/212_ChZDSUhNMG9nS0VJQ0FnSUNobll1UUhBEAEF_fake_reviewImageUrls_2.png
# 213:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/213_ChZDSUhNMG9nS0VJQ0FnSURXcHVPdEFnEAEF_fake_reviewImageUrls_2.png
# 214:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/214_ChZDSUhNMG9nS0VJQ0FnSURDaXQyUktREAEF_fake_reviewImageUrls_2.png
# 215:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/215_ChZDSUhNMG9nS0VJQ0FnSUQ4dDZHOGVnEAEF_fake_reviewImageUrls_2.png
# 216:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/216_ChZDSUhNMG9nS0VJQ0FnSUNnc0o3N0RnEAEF_fake_reviewImageUrls_2.png
# 217:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/217_ChZDSUhNMG9nS0VJQ0FnSURJa3NPN2FREAEF_fake_reviewImageUrls_2.png
# 218:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/218_ChZDSUhNMG9nS0VJQ0FnSURjbzVUUUd3EAEF_fake_reviewImageUrls_2.png
# 219:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/219_ChZDSUhNMG9nS0VJQ0FnSUR1aHJpbEpREAEF_fake_reviewImageUrls_2.png
# 220:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/220_ChdDSUhNMG9nS0VJQ0FnSUNzNUxHZ293RRABF_fake_reviewImageUrls_2.png
# 221:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/221_ChdDSUhNMG9nS0VJQ0FnSURtaXFXX2dRRRABF_fake_reviewImageUrls_2.png
# 222:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/222_ChdDSUhNMG9nS0VJQ0FnSUNLclltNnd3RRABF_fake_reviewImageUrls_2.png
# 223:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/223_ChZDSUhNMG9nS0VJQ0FnSUR1bHQ2Y2FREAEF_fake_reviewImageUrls_2.png
# 224:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/224_ChdDSUhNMG9nS0VJQ0FnSUN1Z3JuZ3FBRRABF_fake_reviewImageUrls_2.png
# 225:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/225_ChZDSUhNMG9nS0VJQ0FnSUNhcnVTYWJREAEF_fake_reviewImageUrls_2.png
# 226:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/226_ChZDSUhNMG9nS0VJQ0FnSUNLdV8tSGJnEAEF_fake_reviewImageUrls_2.png
# 227:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/227_ChZDSUhNMG9nS0VJQ0FnSUNBaV9EM1NREAEF_fake_reviewImageUrls_2.png
# 228:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/228_ChdDSUhNMG9nS0VJQ0FnSUNtcE5pcmxRRRABF_fake_reviewImageUrls_2.png
# 229:	Extracting features from https://raw.githubusercontent.com/MichaelSeitz98/seminararbeit_review_detection/main/02_Images/fake_image_url_2/229_ChZDSUhNMG9nS0VJQ0FnSUN1LXBXYUxnEAEF_fake_reviewImageUrls_2.png
# ...
# 1285:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOclE121jpI-kSMJL5JofNAuxr_LmdunjFWHVpk=w256-h256-p-k-no
# 1286:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMoyesQnfcKM2wottVBFiwRE0sv7LSkcMgq-sC3=w256-h256-p-k-no
# 1287:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM1yCK1sTK2UBpRl4UfKbfsU4RmN38NKy8GkMaX=w256-h256-p-k-no
# 1288:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNICb0CGw398Ck0oawWGfoStOlZucY-eINJzD6f=w256-h256-p-k-no
# 1289:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMZlqWwM9zgs4xF6KPKKstp1MTJjk1O0x08LQAz=w256-h256-p-k-no
# 1290:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPgWoIbzLNSjlthLzN4LaAU5Ab9Z8k2TrgNMX8V=w256-h256-p-k-no
# 1291:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPp7NGJu4scbkIgs16aP7KpFqJf2IXkZjfzKBDQ=w256-h256-p-k-no
# 1292:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNogR8tEU89PQ4eacRq1DrBLqdZBP0ZQ6v45Eyz=w256-h256-p-k-no
# 1293:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNUsvUsF0UjLMhRfMGCn6v67LdCZCGbRgFxqaA-=w256-h256-p-k-no
# 1294:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOPn3klOtWwm1a_n8wSvvKKhnTHDQlc1u-B127O=w256-h256-p-k-no
# 1295:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipO15FE33aIWZjLIzxyQAXlKB9U5JqQ6slh-kaLG=w256-h256-p-k-no
# 1296:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMCaWAakwQ0Uq3RuhuNXJCXYSWpVFA2rjyrowMu=w256-h256-p-k-no
# 1297:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOG5D3N1JCtCiGU7Y7MWXxJizBbMSKJHPKG8wB7=w256-h256-p-k-no
# 1298:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNrPGKA2e-UUS50RaC6K4kI_AbAEL3Keey2TEzQ=w256-h256-p-k-no
# 1299:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOV22wFAh42CMRbywT2x_4ulOOhZrDVgAGxvYF4=w256-h256-p-k-no
# 1300:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNq6W7RUxgTg23AHdwsFwbCl-IJqUp3Rsbv5KEp=w256-h256-p-k-no
# 1301:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPgiEsvUAd996SAkg8Xj5A1gsVFhe6KLoEDlmMK=w256-h256-p-k-no
# 1302:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM3-5B3RT5XQoclXaTv7SaBi9ZWTrvMU768HmVn=w256-h256-p-k-no
# 1303:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPcK_v0mCnSuKlSaNhD3ytz3dQxHXmLPRXed_-A=w256-h256-p-k-no
# 1304:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipP3QkYhgagQg3GfUizyq78eVESxnBAaPPXSAA14=w256-h256-p-k-no
# 1305:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN-fhg8tSARIOHjGGRyDkfYSZ5ldsAPcVvLu2dC=w256-h256-p-k-no
# 1306:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPeyDFBbXb82KCXdpSITpLtkqAqM5J4fHG4jIkz=w256-h256-p-k-no
# 1307:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPzPZPZkT592CdwtNkvObib6_F7yFp2JCDXBcN8=w256-h256-p-k-no
# 1308:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMHrw1NRtTTeMVvsFB90S_giMt-8vy6s4iU62Wt=w256-h256-p-k-no
# 1309:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNcPisjpbkgUSLnrv_L3ppS4pQmU_U_FgsteXSb=w256-h256-p-k-no
# 1310:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPyf5K6MWjNVtJ1QLfO8CAZP2hsz_5CqrBw9QeJ=w256-h256-p-k-no
# 1311:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMBTV3wrVU_8_MNFkOGOLlmRgNgTlSWhXvxbsBw=w256-h256-p-k-no
# 1312:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPI9wcZql3w-hI7j0KuE1VbwndF1jEx2xtjAsx1=w256-h256-p-k-no
# 1313:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNDk6gGVIn82HuI-ZJkgv3fvu5A7PlaKGWHXR3x=w256-h256-p-k-no
# 1314:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNgz4XurZM54V3Z0gOBuxmQKp4o_2WbkYFYF9_T=w256-h256-p-k-no
# 1315:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPZGiq69XJZFmGAdGCxqK6J8M3TYuYaBOVDUm4Q=w256-h256-p-k-no
# 1316:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNU4lrRELSb543tIgB_eMGpY-wSWiYMw1bwtML1=w256-h256-p-k-no
# 1317:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPqgTmrG9yxM8wdnBYeflNIaGO7MEmbaGpBdJ-L=w256-h256-p-k-no
# 1318:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN8lcJlwGh24EFKsjv0b-CmKp4wF3V6MUdjDYeM=w256-h256-p-k-no
# 1319:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNgNO--eBeUWJYGsTIdYJtmXdZAeCWDxOuiHZGq=w256-h256-p-k-no
# 1320:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipO0Kk2IN3whz2BaD78uxKQCs-cyCy5fExwGhQkv=w256-h256-p-k-no
# 1321:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPdpXMlWw-0d8QsotAHY8R3N_qwne39GLumRKnz=w256-h256-p-k-no
# 1322:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPoay5kH4dthf5yOo_ZE7Ey6GsbSU162Qjleyr1=w256-h256-p-k-no
# 1323:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNliGxyEiacBIy425CP2qfJ7wqWQEVM7VFWxzQ8=w256-h256-p-k-no
# 1324:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPhH5IUv8iqBYklKApwZFLzj0YMAWRITwkgx-vo=w256-h256-p-k-no
# 1325:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM2CwoOIVfdcQbgx1SReoPG54ySVD9IWJ5itOcd=w256-h256-p-k-no
# 1326:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNLWSfiJHRzLOHfunBQhtGFEjagAkg46ofd54UT=w256-h256-p-k-no
# 1327:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPzi5K5THowqbWxp--YuzkAon9ZSZYvcPpmQ5pU=w256-h256-p-k-no
# 1328:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMztDDqQWHFuAEOEI2VSZ72zX0yTEqFkesQ_-65=w256-h256-p-k-no
# 1329:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNxRWhFsKSCFnM8ACXK4kCYsAFiqg3cbpbNADXr=w256-h256-p-k-no
# 1330:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPVtk8bL6IPIXs8V_Vn3aL6IQWcIT2X8WOnAXB-=w256-h256-p-k-no
# 1331:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOHVs97GaOiA-qPhwIwlYvuMKrjZCS8ppzK_Ef0=w256-h256-p-k-no
# 1332:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMHCI0I4Vd3XXj6rlLlZ3yVJlrAfsgfAAGPdqjx=w256-h256-p-k-no
# 1333:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMnhuPEUAQNhEEsD-iP5SfJuoNeS5zXzj5PY_kN=w256-h256-p-k-no
# 1334:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNw4czWQlsFSwhAo854nYgxq-H0jHZpRBZ_GYnD=w256-h256-p-k-no
# 1335:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMcZN14RSUrdAWEXkYZCeo35n18jr9b42wjvS4_=w256-h256-p-k-no
# 1336:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPPl-iIfKQIKb4mGhAYcBBvAkWBCF4t0vLUfQgQ=w256-h256-p-k-no
# 1337:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMvdjXSY5ihVWRFemrE6JSbersZHNd8TB5OjdSh=w256-h256-p-k-no
# 1338:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN-dPeg-UAo9LXYrPg6CZxYc_gg3uUkJuqgjLUI=w256-h256-p-k-no
# 1339:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipObgDILu4A4vKcvl5C2Xsi_qkG36CtIOfuHf88t=w256-h256-p-k-no
# 1340:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPV8IroZ52okqEsoia-HlwiDwoM3u-JMosqey5H=w256-h256-p-k-no
# 1341:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNHX1Tukm8fkU2H2Oy9LmcnYeE-xouto4MV1vWo=w256-h256-p-k-no
# 1342:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPgahRXCg06HZVvWwiVsN_xgSMRYVZl3qf7V9KE=w256-h256-p-k-no
# 1343:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNf2ToAt16BA_Q7UBWBi6kQ7k_hM4WTMjIiewd9=w256-h256-p-k-no
# 1344:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNsZAYzdT1hBwTa5fJPq4v9znN-lVU8xsPe8mE=w256-h256-p-k-no
# 1345:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOObj8teR9WRKbcv52QuJMnOTfRdB6CW7TAQCIb=w256-h256-p-k-no
# 1346:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOIMxAQ91HyAqbyw_ICcQvCBWQLT05O2MEOQJfM=w256-h256-p-k-no
# 1347:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOUYn-vF9cN1f_lxa-2RR9kX0JlBNz6N58C_s51=w256-h256-p-k-no
# 1348:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPg3u06knvAoRMm6o_GvOfalGoSPDOhGZod-U-S=w256-h256-p-k-no
# 1349:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipONayA7l2Bb9rdoTPubt_Q12Gi0Ip1isXCily0m=w256-h256-p-k-no
# 1350:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOHr1tsiUDvLkaGBKZiCqPZH2MaYpwQZpZnS-7O=w256-h256-p-k-no
# 1351:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPVXkkN3fAEbb5CBiwzF056lzldv32hip5rYawu=w256-h256-p-k-no
# 1352:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM_E1f-FyEb12o1QwTX-5-mBA0eURKNxQA-ejKq=w256-h256-p-k-no
# 1353:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM1O6cZ9CsTdZ0OautIgK_oX1-c37kdZBAE4nPh=w256-h256-p-k-no
# 1354:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN7CyZN0QRwyMkvW9yLFyXAEXQFJfk3CUqglFW2=w256-h256-p-k-no
# 1355:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPc39xj4EVCkwYXUKzLIO9UrrNcNF2wwhrxwTxl=w256-h256-p-k-no
# 1356:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMUGKHafmg1GLfA5jBmY8UKMNg44BUnolhgsBG4=w256-h256-p-k-no
# 1357:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipP3l9ab3U9Q-rTSgeUGZoVXa6ZtsATP87TQ6v8X=w256-h256-p-k-no
# 1358:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMV579INVJC5dtA6muHLAFHKGyefY4_CXS0IJ10=w256-h256-p-k-no
# 1359:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOHue3GtI7UsfnFzfEYmOUtcNJ71e5QXrgGZH-X=w256-h256-p-k-no
# 1360:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNyp39LJSrRlpnpX-Ns6j1H8_qaCga7Uw_ruaMc=w256-h256-p-k-no
# 1361:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNDMtewyw0ic7_8CDxc-XY_NVjr9upJCb5rCgOV=w256-h256-p-k-no
# 1362:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNyXCIaoKLnJXh0tMe8xB3dxpo8FVhZSyokf344=w256-h256-p-k-no
# 1363:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMrRzp_nL7LW4QMh5TnTkuOlolOg7cFiB2gU3UT=w256-h256-p-k-no
# 1364:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMlf8GfdkLcQl1lADWjzMLu1YHdag9DsbvPpYih=w256-h256-p-k-no
# 1365:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPeF0cC1Dq6cBf7nSxsZd8a5mDHl99IDv_oM8Tw=w256-h256-p-k-no
# 1366:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN8ga69tkEE2vfPhV1nktrJSNdsVSrOvYbOR2sX=w256-h256-p-k-no
# 1367:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPho3vafI4ns__kKqNQ7Madnc9_jo_JGyRpksCX=w256-h256-p-k-no
# 1368:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN8hZE63WWsn2HpUiB7B-XpJJ8yYgX5nkYBFL4h=w256-h256-p-k-no
# 1369:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMh4hsKs1K0DFoMho3RPQfW6nuc4oCxe58kP6Bf=w256-h256-p-k-no
# 1370:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMjJUO5kbNjIzK7sHZP8klUSEEgetvB62qAonU-=w256-h256-p-k-no
# 1371:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMNpONi4jvx7GRvzaqS-J9XixZjd4Cye-hYt3LO=w256-h256-p-k-no
# 1372:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMxrgT9WqrTZx4QPUubN_rOMKFUNHj56NhLqGB4=w256-h256-p-k-no
# 1373:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOcTXHZFP78N5ZQnNBXeDwfasNZbuD5pLMf80xd=w256-h256-p-k-no
# 1374:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNPnVplZ7I7izw2LIv-XREMAkxjn-RJA6yJoYJ-=w256-h256-p-k-no
# 1375:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOWfn9QSXSl3wpsj-jDMc8cvGDFJECizHee5jvr=w256-h256-p-k-no
# 1376:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOTd9zCwB_9HujTtWff23bBSNqJ3RuHkITxUla2=w256-h256-p-k-no
# 1377:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNk4V4vwemRMHZI9w7JX623_hEaCuV5dK-XeNTW=w256-h256-p-k-no
# 1378:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN8nl9fgfh6sEnFKRZO5CsFxtBUktLJRBk-VFW_=w256-h256-p-k-no
# 1379:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM5xb_-H0k2c6TybN-Jd2L1FXkdF3YfVmNUcJ0I=w256-h256-p-k-no
# 1380:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNK3vRiiI_Bxy5fLKDdKL8zzgrjOZBbsyLGBdkc=w256-h256-p-k-no
# 1381:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPnfaNonhcOcK5-OECtJPWPqvylQ7gR2DB2cl5X=w256-h256-p-k-no
# 1382:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPZHA8qevCFV3A5rr_Q6UtB3Heyque_iorZka5X=w256-h256-p-k-no
# 1383:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipP2REGpo4CXPJNQoG70INbIgKEqN4hSeiv3_rab=w256-h256-p-k-no
# 1384:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPVm8BXmrDdqgRXW08awm1qTT4nsxLV01qFLl31=w256-h256-p-k-no
# 1385:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipN2vg-IO0i9-JyqCO9LGAClrk_mmMtMfLJHhoNl=w256-h256-p-k-no
# 1386:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipM3f8UpqqDyD1_ymL2ALYZNgV-zxH9HyH00ycRT=w256-h256-p-k-no
# 1387:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNlCB81l-D_a2HT2YYWc4LTUboEHOJCc5zu5UaX=w256-h256-p-k-no
# 1388:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipONXRTnjK1SuYKSKivRhvPzlumIeohIOeroI6vq=w256-h256-p-k-no
# 1389:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPRGd2TS2Qsv6iqXfPRlggtTtfSXRvrSGYNVjpc=w256-h256-p-k-no
# 1390:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOcWafqH6_r2VThs_s_OByn3ruVE9j611VrdYyi=w256-h256-p-k-no
# 1391:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMTT2yXtoG_qXYSYJtRCSs9vfUeZkx9Tf8dqJGg=w256-h256-p-k-no
# 1392:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipOfDY6zN_XDTEZy_PLT4SWY00OOzW85eVG4qlyV=w256-h256-p-k-no
# 1393:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPdGshz4469M7ehG9o_Cp0MB5wk08KUGBPwV8gi=w256-h256-p-k-no
# 1394:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMLtfNZ9UVWrxxm7zc33ays8CRLtF8ReD9f2dt6=w256-h256-p-k-no
# 1395:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMVDsJCeqF7Hv0gCoevCladddZKWP-WMXXAILg4=w256-h256-p-k-no
# 1396:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMvEHNWm5KUrYqOTORxeCYg6WpWW5yB3ijBHj83=w256-h256-p-k-no
# 1397:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNA34uc0w2T6apbri3dJs-Dsr13nxS8l3lnKDXR=w256-h256-p-k-no
# 1398:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMoU3-HflZrE5LgW0XMmGORi3T9_3sh0JGD6C4G=w256-h256-p-k-no
# 1399:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMCRpYoEe_SbOL024O17PZ65mnKaFlnel-1HSjp=w256-h256-p-k-no
# 1400:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNaFmYrUov0m59cxsh1KzCuh72C3vYLb3Y4l9am=w256-h256-p-k-no
# 1401:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipP5oQfNJJhc82JuLy6-XIlljr-vFiVMlf9Erp6x=w256-h256-p-k-no
# 1402:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNzoW16RF9G3fZjLkgPWkqVYbA4ZyHweUsCv87o=w256-h256-p-k-no
# 1403:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipP7ZZ8MTZAZ7lCDgro9bPdVuSkOAou_h30eVN6t=w256-h256-p-k-no
# 1404:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipPeYm4PQSinsQtYYNQ4LYl9lyCo6dhJDBamYVQC=w256-h256-p-k-no
# 1405:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipMcT6mnSf7KQ1bq1t1wzcEqcbTXVh0zfPAwx0H4=w256-h256-p-k-no
# 1406:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNSfoGJPcFoQxzbJB80aG_kSTkv1hrc-wPAC-EL=w256-h256-p-k-no
# 1407:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNGi9yHsKX5RiDRmHiPlJuW0ylWnNy2ZFVUKrYj=w256-h256-p-k-no
# 1408:	Extracting features from https://lh5.googleusercontent.com/p/AF1QipNdt-skNxsWFOlehP7axXhRLqTaalORDTQvBug7=w256-h256-p-k-no

# %%
new_df = pd.concat([df, feature_df], axis=1)
print("added features to the original dataset.")
new_df.to_csv('feature_enriched_tab_img2_text_preproc.csv', index=False)
# Out:
# added features to the original dataset.
# label                                                                                                                                                                                                               0
# reviewId                                                                                                                                                                         ChdDSUhNMG9nS0VJQ0FnSURXaV9mQ2lnRRAB
# placeId                                                                                                                                                                                   ChIJ4XfXK_G8woARbUYxTMpyDo8
# reviewUrl          https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURXaV9mQ2lnRRAB!2m1!1s0x0:0x8f0e72ca4c31466d!3m1!1s2@1:CIHM0ogKEICAgIDWi_fCigE%7CCgwI8c2qkgYQiNvSywE%7C?hl=en-US
# url                 https://www.google.de/maps/place/Hotel+Bel-Air/@34.0049838,-118.5864972,10z/data=!4m9!3m8!1s0x80c2bcf12bd777e1:0x8f0e72ca4c31466d!5m2!4m1!1i2!8m2!3d34.086597!4d-118.446351!16zL20vMGcxbDNm?hl=en
#                                                                                                                   ...
# img_feature_507                                                                                                                                                                                              1.943444
# img_feature_508                                                                                                                                                                                               0.46656
# img_feature_509                                                                                                                                                                                              1.002254
# img_feature_510                                                                                                                                                                                              1.385998
# img_feature_511                                                                                                                                                                                               1.14086
# Name: 762, Length: 1086, dtype: object

# %% [markdown]
# ## Verschiedene Visualisierung der Bild-Feature-Extraktion
#
# 1. Visualisierung des 512-dimensionaler Feature-Vektors mit PCA für Intuition
# 2. Visualisierung des Extraktionsprozess eines gefakten Beispielbildes (von reviewImageUrls/2)  während des CNN-Durchlaufs
# 3. Visualisierung der extrahierten Features
# 4. Visualisierung der Filteroperationen des CNNs

# %% [markdown]
# ### Visualisierung des 512-dimensionaler Feature-Vektors mit PCA für Intuition

# %%
df = pd.read_csv('feature_enriched_tab_img.csv')

# die Zeile droppen, weil korrupter Image-Url und deshalb keine Features extrahiert werden konnten
df = df.drop(764)
# nur die img_features behalten und das label
features = df.iloc[:, 0:1].join(df.iloc[:, 24:])
features = features.dropna(subset=features.columns[1:], how='all')

color_map = {'fake': 'red', 'real': 'green'}
colors = features['label'].apply(lambda x: color_map[x])

# PCA durchführen um die Features auf 2 Dimensionen reduzieren
pca = PCA(n_components=2)
pca_features = pca.fit_transform(features.iloc[:, 1:])

plt.figure(figsize=(8, 6))
plt.scatter(pca_features[:, 0], pca_features[:, 1], c=colors, alpha=0.5, s=50)
plt.xlabel('PCA Komponente 1', fontsize=14)
plt.ylabel('PCA Komponente 2', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=10)
plt.grid(alpha=0.2)
plt.legend(handles=[plt.scatter([], [], c='red', label='Fake Bild', alpha=0.5, s=50),
                     plt.scatter([], [], c='green', label='Echtes Bild', alpha=0.5, s=50)],
           loc='upper right', fontsize=12)
plt.savefig('02_Images\graphics\pca_feature_extraction.svg', format='svg')
plt.show()

# %% [markdown]
# ### Visualisierung des Extraktionsprozesses während CNN-Durchlauf
#
# Visualisierung der Bilder nach den angewendeten Operationen für jede Layer anhand eines Beispielbildes

# %%
resnet = models.resnet18(pretrained=True)

# Funktion, die für ein gegebenes Bild die Feature Maps eines Layers visualisiert
def visualize_layer_features(layer_num, input_img):
    layer = resnet.layer1[layer_num]

    outputs = []
    def hook(module, input, output):
        outputs.append(output)
    layer.register_forward_hook(hook)

    # Durch das Modell forward passen
    _ = resnet(input_img)
    feature_maps = outputs[0].detach().numpy()

    # Plot the feature maps as a grid
    fig, axs = plt.subplots(nrows=8, ncols=8, figsize=(12, 12))
    axs = axs.flatten()
    for i in range(64):
        axs[i].imshow(feature_maps[0, i, :, :], cmap='gray')
        axs[i].axis('off')
    plt.tight_layout()

    fig.savefig(f"layerWW{layer_num}.png")
    plt.close(fig)


# Anhand eines durch Dalle-2 erzeugten Beispielbildes die Feature Maps visualisieren

img_path = '02_Images/fake_image_url_2/43_ChZDSUhNMG9nS0VJQ0FnSURRdTh6UEJnEAEF_fake_reviewImageUrls_2.png'
img = Image.open(img_path)
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
input_img = transform(img)
input_img = input_img.unsqueeze(0)

if not os.path.exists('feature_maps'):
    os.makedirs('feature_maps')

# Für die verschiedenen Layer die Feature Maps visualisieren
for i in range(4):
    visualize_layer_features(i, input_img)

# %% [markdown]
# ### Visualisierung der extrahierten Features
#
#
# Ergebnis: siehe 02_Images\visualizations_image_features. Für menschliches Auge keine klaren Muster erkennbar.

# %%
def visualize_and_save_feature(model, feature_index, save_dir, num_iterations=500):
    model.eval()
    input_image = torch.randn(1, 3, 224, 224, requires_grad=True)
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

    optimizer = torch.optim.Adam([input_image], lr=0.1)

    for i in range(num_iterations):
        optimizer.zero_grad()
        output = model(input_image)
        feature_activation = output[0, feature_index].mean()
        feature_activation.backward()
        optimizer.step()

    input_image = input_image.detach().numpy()[0]
    input_image = (input_image * np.array([0.229, 0.224, 0.225]).reshape((3, 1, 1))) + np.array([0.485, 0.456, 0.406]).reshape((3, 1, 1))
    input_image = np.clip(input_image, 0, 1)
    filename = f'feature_{feature_index}.png'
    save_path = os.path.join(save_dir, filename)
    plt.imsave(save_path, np.transpose(input_image, (1, 2, 0)))

save_dir = '02_Images/visualizations_image_features'
os.makedirs(save_dir, exist_ok=True)

for i in range(511, 512):
    visualize_and_save_feature(model, i+1, save_dir)

# %% [markdown]
# ### Visualisierung der Filteroperationen des CNNs

# %%
resnet = torch.hub.load('pytorch/vision', 'resnet18', pretrained=True)

conv1 = resnet.conv1
fig, axs = plt.subplots(8, 8, figsize=(10, 10))

for i in range(8):
    for j in range(8):
        filter_idx = i * 8 + j
        filter_img = conv1.weight.data[filter_idx].cpu().numpy().transpose(1, 2, 0)
        axs[i, j].imshow(filter_img)
        axs[i, j].axis('off')

plt.show()

# %% [markdown]
# # Text: Feature Extraktion
#
# 1. Snytaktische Feature extrahieren über NLTK Paket, wie z.B: length, adverb, Großklein, Rechtschriebung, Smiley-Nutzung, usw.
# 2. Semantische Features wie Sentiment (xml_roberat) oder LDA-Topics

# %%
model_path = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
sentiment_task = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)

# %%
df = pd.read_csv("feature_enriched_tab_img.csv")

def entire_capitalized_percentage(text):
    words = text.split()
    num_words = len(words)
    words = [word for word in words if word.lower() != "i"]
    num_capitalized = sum([1 for word in words if word.isupper()])
    return num_capitalized / num_words

def count_emojis(text):
    emoji_count =  0
    for character in text:
        if character in emoji.EMOJI_DATA:
            emoji_count += 1
    return emoji_count

def emojji_per_word_ratio(text):
    emoji_count =  0
    for character in text:
        if character in emoji.EMOJI_DATA:
            emoji_count += 1
    words = text.split()
    num_words = len(words)
    if num_words == 0:
        return 0
    else:
        return emoji_count / num_words
    
def avg_word_length(text):
    words = text.split()
    num_words = len(words)
    if num_words == 0:
        return 0
    else:
        total_length = sum([len(word) for word in words])
        return total_length / num_words

def avg_sentence_length(text):
    sentences = nltk.sent_tokenize(text)
    num_sentences = len(sentences)
    if num_sentences == 0:
        return 0
    else:
        total_length = sum([len(sentence.split()) for sentence in sentences])
        return total_length / num_sentences

def extract_pos_tags(text):
    pos_tags = nltk.pos_tag(nltk.word_tokenize(text))
    return pos_tags

def perform_sentiment_analysis(text):
    try:
        sentiment = sentiment_task(text)
        sentiment_label = sentiment[0]['label']
        #print(sentiment_label)
        return sentiment_label
    except RuntimeError:
        print(f"RuntimeError bei Text:    {text}")
        return "check_manually"
   
def text_spelling_error_quota(text):
    blob = TextBlob(text)
    words = blob.words
    num_words = len(words)
    num_errors = sum([not w.spellcheck()[0][1] for w in blob.words])
    return num_errors / num_words

def calculate_punctuation_ratio(text):
    sentences = sent_tokenize(text)
    ratio_list = []
    for sentence in sentences:
        words = word_tokenize(sentence)
        num_punctuations = sum([1 for word in words if word in string.punctuation])
        num_words = len(words)
        if num_words > 0:
            punctuation_ratio = num_punctuations / num_words
            ratio_list.append(punctuation_ratio)    
    if len(ratio_list) > 0:
        avg_punctuation_ratio = sum(ratio_list) / len(ratio_list)
    else:
        avg_punctuation_ratio = 0
    return avg_punctuation_ratio

def count_nouns(text):
    tokens = nltk.word_tokenize(text)
    tagged_tokens = nltk.pos_tag(tokens)
    noun_count = len([word for word, tag in tagged_tokens if tag.startswith('N')])
    return noun_count

def count_adjectives(text):
    adj_tags = ['JJ', 'JJR', 'JJS']
    tokens = nltk.word_tokenize(text)
    adj_count = len([word for word, tag in nltk.pos_tag(tokens) if tag in adj_tags])
    return adj_count

def count_verbs(text):
    stop_words = set(stopwords.words('english'))
    verb_tags = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
    tokens = word_tokenize(text)
    verb_count = len([word for word, tag in pos_tag(tokens) if tag in verb_tags and word.lower() not in stop_words])
    return verb_count

def count_adverbs(text): 
    stop_words = set(stopwords.words('english'))
    adv_tags = ['RB', 'RBR', 'RBS']
    tokens = word_tokenize(text)
    adv_count = len([word for word, tag in pos_tag(tokens) if tag in adv_tags and word.lower() not in stop_words])
    return adv_count

def count_pronouns(text):
    pronoun_tags = ['PRP', 'PRP$', 'WP', 'WP$']
    tokens = word_tokenize(text)
    pronoun_count = len([word for word, tag in pos_tag(tokens) if tag in pronoun_tags])
    return pronoun_count

def calculate_not_stopword_ratio(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    num_words = len(words)
    not_stopword_count = len([word for word in words if word.lower() not in stop_words])
    return not_stopword_count / num_words

def calculate_stopword_ratio(text):
    words = nltk.word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    num_words = len(words)
    num_stopwords = len([word for word in words if word in stop_words])
    return num_stopwords / num_words

def calulate_stopword_to_nostopword_ratio(text): 
    return calculate_stopword_ratio(text) / calculate_not_stopword_ratio(text)

def compute_modal_verb_ratio(text):
    tokens = nltk.word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    modal_verbs = ['can', 'could', 'may', 'might', 'shall', 'should', 'will', 'would', 'must']
    modal_verb_count = len([word for word in tokens if word in modal_verbs and word not in stop_words])
    word_count = len([word for word in tokens if word not in stop_words])
    return modal_verb_count / word_count

def compute_uncertain_ratio(text):
    words = nltk.word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    uncertain_words = ['yet', 'careful', 'hesitant', 'tendency', 'hit', 'undefined', 'ambivalent', 'confused', 'equivocal', 'fuzzy', 'inconclusive', 'indeterminate', 'unclear', 'uncertain', 'unsettled', 'vague']
    uncertain_count = len([word for word in words if word in uncertain_words and word not in stop_words])
    total_count = len(words)
    uncertain_ratio = uncertain_count / total_count if total_count > 0 else 0.0
    return uncertain_ratio

def count_individual_words(text):
    individual_words = ['I', 'me', 'my', 'mine', 'myself']
    tokens = word_tokenize(text)
    individual_count = len([word for word in tokens if word.lower() in individual_words])
    return individual_count

def count_group_words(text):
    group_words = ['we', 'us', 'our', 'ours', 'ourselves']
    tokens = word_tokenize(text)
    group_count = len([word for word in tokens if word.lower() in group_words])
    return group_count

def count_self_words(text):
    self_words = ['self', 'myself', 'ourselves']
    tokens = word_tokenize(text)
    self_count = len([word for word in tokens if word.lower() in self_words])
    return self_count

def individual_ratio(text):
    total_words = len(word_tokenize(text))
    individual_count = count_individual_words(text)
    return individual_count / total_words

def group_ratio(text):
    total_words = len(word_tokenize(text))
    group_count = count_group_words(text)
    return group_count / total_words

def self_ratio(text):
    total_words = len(word_tokenize(text))
    self_count = count_self_words(text)
    return self_count / total_words

df['text_length'] = df['text'].apply(lambda x: len(str(x).split()))
df['text_length_char'] = df['text'].apply(len)
df['text_punctuation'] = df['text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]))
df['text_avg_word_length'] = df['text'].apply(avg_word_length)
df['text_avg_sentence_length'] = df['text'].apply(avg_sentence_length)
df['text_sentiment'] = df['text'].apply(perform_sentiment_analysis)
print('Fertig mit 1. Block.')

df['text_emoji_count'] = df['text'].apply(count_emojis)
df['text_count_verbs'] = df['text'].apply(count_verbs)
df['text_count_adjectives'] = df['text'].apply(count_adjectives)
df['text_count_adverbs'] = df['text'].apply(count_adverbs)
df['text_count_pronouns'] = df['text'].apply(count_pronouns)
df['text_count_nouns'] = df['text'].apply(count_nouns)
df.to_csv('features_enriched_tab_img_text.csv', index=False)
print('Fertig mit 2. Block.')

df['text_no_stopword_Ratio'] = df['text'].apply(calculate_not_stopword_ratio)
df['text_stopword_ratio'] = df['text'].apply(calculate_stopword_ratio)
df['text_stopword_to_nostopword_ratio'] = df['text'].apply(calulate_stopword_to_nostopword_ratio)
df['text_entired_capitalized_ratio'] = df['text'].apply(entire_capitalized_percentage)
df['text_punctuation_ratio'] = df['text'].apply(calculate_punctuation_ratio)
df.to_csv('features_enriched_tab_img_text.csv', index=False)
print('Fertig mit 3. Block.')

df['text_spelling_error_quota'] = df['text'].apply(text_spelling_error_quota)
df['text_modal_verb_ratio'] = df['text'].apply(compute_modal_verb_ratio)
df['text_uncertain_ratio'] = df['text'].apply(compute_uncertain_ratio)
df['text_individual_count'] = df['text'].apply(count_individual_words)
print('Fertig mit 4. Block.')

df['text_group_count'] = df['text'].apply(count_group_words)
df['text_self_count'] = df['text'].apply(count_self_words)
df['text_individual_ratio'] = df['text'].apply(individual_ratio)
df['text_group_ratio'] = df['text'].apply(group_ratio)
df['text_self_ratio'] = df['text'].apply(self_ratio)
print('Fertig mit 5. Block.')

df.to_csv('features_enriched_tab_img_text.csv', index=False)

# %% [markdown]
# Nachträglich hinzugefügtes Feature: **text_exclamation_mark_count**  und **text_exclamation_mark_ratio**

# %%
df = pd.read_csv('features_enriched_tab_img_text.csv')
print(df.shape)
print(df.columns)
print(df.head(20))

df['text_exclamation_mark_count'] = df['text'].apply(lambda x: str(x).count('!'))
df['text_exclamation_mark_ratio'] = df['text_exclamation_mark_count'] / df['text_length']

print(df[['text_exclamation_mark_count', 'text', 'text_exclamation_mark_ratio']])
print(df[df['reviewId'] == 'ChZDSUhNMG9nS0VJQ0FnSUMweU5uV1BnEAEF']['text'])
print(df [df['text_exclamation_mark_count'] > 0][['text_exclamation_mark_count', 'text', 'text_exclamation_mark_ratio']])
print(df.shape)

# df.to_csv('features_enriched_tab_img_text.csv', index=False)
# df.to_excel('features_enriched_tab_img_text.xlsx', index=False)

# %% [markdown]
# **Latent Dirichlet Allocation (LDA)** angewendet um Texte in Topics einzuteilen. Anschließende Visualisierung mit *pyLDAvis*

# %%
df = pd.read_csv('features_enriched_tab_img_text.csv')

def preprocess_text(text):
    return [token for token in simple_preprocess(text) if token not in STOPWORDS]

processed_texts = [preprocess_text(text) for text in df['text']]
dictionary = corpora.Dictionary(processed_texts)
bow_corpus = [dictionary.doc2bow(text) for text in processed_texts]
n_topics = 10
lda_model = gensim.models.ldamodel.LdaModel(bow_corpus, num_topics=n_topics, id2word=dictionary)

topic_distributions = []
for i in range(len(bow_corpus)):
    topic_distribution = lda_model[bow_corpus[i]]
    topic_distribution_dict = dict(topic_distribution)
    topic_distribution_list = [topic_distribution_dict[i] if i in topic_distribution_dict else 0 for i in range(n_topics)]
    topic_distributions.append(topic_distribution_list)

topic_df = pd.DataFrame(topic_distributions, columns=[f"text_topic_{i}" for i in range(n_topics)])
df = pd.concat([df, topic_df], axis=1)

print(df[df.columns[pd.Series(df.columns).str.startswith('text_topic')]].head(20))

vis = gensimvis.prepare(lda_model, bow_corpus, dictionary)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis)

pyLDAvis.save_html(vis, '02_Images/graphics/lda_visualization3.html')
df.shape
df.to_csv('features_enriched_tab_img_text.csv', index=False)
